# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-7f547460-7c1f-4e58-8576-6a18060d61c9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7f547460-7c1f-4e58-8576-6a18060d61c9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ionosphere_data.csv to ionosphere_data.csv

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import models,layers
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv('ionosphere_data.csv')
data
# Out:
#      feature1  feature2  feature3  ...  feature33  feature34  label
# 0           1         0   0.99539  ...    0.18641   -0.45300      g
# 1           1         0   1.00000  ...   -0.13738   -0.02447      b
# 2           1         0   1.00000  ...    0.56045   -0.38238      g
# 3           1         0   1.00000  ...   -0.32382    1.00000      b
# 4           1         0   1.00000  ...   -0.04608   -0.65697      g
# ..        ...       ...       ...  ...        ...        ...    ...
# 346         1         0   0.83508  ...    0.90546   -0.04307      g
# 347         1         0   0.95113  ...    0.91483    0.04712      g
# 348         1         0   0.94701  ...    0.92697   -0.00577      g
# 349         1         0   0.90608  ...    0.87403   -0.16243      g
# 350         1         0   0.84710  ...    0.85764   -0.06151      g
#
# [351 rows x 35 columns]

# %%
data.label.unique()
# Out:
# array(['g', 'b'], dtype=object)

# %%
data.label=data.label.map({'g':1,'b':2})
data.label
# Out:
# 0      1
# 1      2
# 2      1
# 3      2
# 4      1
#       ..
# 346    1
# 347    1
# 348    1
# 349    1
# 350    1
# Name: label, Length: 351, dtype: int64

# %%
data
# Out:
#      feature1  feature2  feature3  ...  feature33  feature34  label
# 0           1         0   0.99539  ...    0.18641   -0.45300      1
# 1           1         0   1.00000  ...   -0.13738   -0.02447      2
# 2           1         0   1.00000  ...    0.56045   -0.38238      1
# 3           1         0   1.00000  ...   -0.32382    1.00000      2
# 4           1         0   1.00000  ...   -0.04608   -0.65697      1
# ..        ...       ...       ...  ...        ...        ...    ...
# 346         1         0   0.83508  ...    0.90546   -0.04307      1
# 347         1         0   0.95113  ...    0.91483    0.04712      1
# 348         1         0   0.94701  ...    0.92697   -0.00577      1
# 349         1         0   0.90608  ...    0.87403   -0.16243      1
# 350         1         0   0.84710  ...    0.85764   -0.06151      1
#
# [351 rows x 35 columns]

# %%
X = data.iloc[:,:-1]  
y = data.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2) 
X_train.shape
# Out:
# (280, 34)

# %%
models=tf.keras.models.Sequential([tf.keras.layers.Dense(512,activation=tf.nn.relu),tf.keras.layers.Dense(10,activation=tf.nn.softmax)])
models.compile(optimizer=tf.keras.optimizers.Adam(),loss='sparse_categorical_crossentropy',metrics=['accuracy'])
models.fit(X_train,y_train,epochs=15,batch_size=128)
# Out:
# Epoch 1/15
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-39e9b3f7e660> in <module>()
#       2 models=tf.keras.models.Sequential([tf.keras.layers.Dense(512,activation=tf.nn.relu),tf.keras.layers.Dense(10,activation=tf.nn.softmax)])
#       3 models.compile(optimizer=tf.keras.optimizers.Adam(),loss='categorical_crossentropy',metrics=['accuracy'])
# ----> 4 models.fit(X_train,y_train,epochs=15,batch_size=128)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# ...

# %%
models.evaluate(X_test,y_test)
# Out:
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4647 - accuracy: 0.8310
# [0.4646854102611542, 0.8309859037399292]

# %%
models.predict(X_test)
# Out:
# array([[4.39315299e-05, 7.68385768e-01, 2.31183350e-01, 6.96818461e-05,
#         6.15892714e-05, 6.94401024e-05, 6.95722119e-05, 4.51228407e-05,
#         3.96167561e-05, 3.19544997e-05],
#        [4.47433631e-05, 9.34369206e-01, 6.51324615e-02, 7.39107272e-05,
#         7.71104969e-05, 7.80304545e-05, 7.47978702e-05, 6.21954096e-05,
#         4.88480036e-05, 3.85401909e-05],
#        [6.21614978e-04, 8.12682986e-01, 1.80646628e-01, 7.91400846e-04,
#         1.13850692e-03, 1.17036782e-03, 8.48892902e-04, 7.81824987e-04,
#         6.85191015e-04, 6.32549694e-04],
#        [6.62491983e-03, 8.22365522e-01, 1.12414993e-01, 7.38883857e-03,
#         1.02315275e-02, 1.15244016e-02, 7.83972442e-03, 9.47074965e-03,
#         5.98107930e-03, 6.15811674e-03],
#        [5.70714585e-02, 1.56043440e-01, 3.82578313e-01, 4.91764545e-02,
#         6.79988042e-02, 6.11188859e-02, 5.95971569e-02, 5.99552505e-02,
#         5.40028252e-02, 5.24574704e-02],
# ...

# %%
y_test
# Out:
# 25     2
# 243    1
# 267    1
# 266    1
# 230    2
#       ..
# 128    2
# 35     2
# 244    2
# 212    2
# 10     1
# Name: label, Length: 71, dtype: int64
